# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45460 entries, 0 to 45459
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 45460 non-null  bool
#  1   budget                45460 non-null  int64
#  2   genres                43018 non-null  object
#  3   id                    45460 non-null  int64
#  4   original_language     45449 non-null  object
#  5   popularity            45460 non-null  float64
#  6   production_companies  33585 non-null  object
#  7   production_countries  39178 non-null  object
#  8   release_date          45376 non-null  object
#  9   revenue               45460 non-null  int64
#  10  runtime               45203 non-null  float64
#  11  title                 45460 non-null  object
#  12  video                 45460 non-null  bool
#  13  vote_average          45460 non-null  float64
#  14  vote_count            45460 non-null  int64
# ...

# %%
data = pd.read_csv("replset.csv")

# %%
data.dropna(inplace=True)#drop any rows which has missing values

# %%
data.production_companies.value_counts()
# Out:
# Metro-Goldwyn-Mayer (MGM)                                                      729
# Warner Bros.                                                                   535
# Paramount Pictures                                                             498
# Twentieth Century Fox Film Corporation                                         427
# Universal Pictures                                                             316
#                                                                               ...
# Lighthouse Pictures, Craig Anderson Productions, Let it Snow Productions         1
# Black & Blue Films, Fyzz Factory, The, Size 9 Productions                        1
# Rai Cinema, One More Pictures                                                    1
# Le Monde Entertainment, , Planet Productions, Planet Productions                 1
# Walt Disney Pictures, Jerry Bruckheimer Films, Moving Picture Company (MPC)      1
# Name: production_companies, Length: 22188, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32671 entries, 0 to 45459
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 32671 non-null  bool
#  1   budget                32671 non-null  int64
#  2   genres                32671 non-null  object
#  3   id                    32671 non-null  int64
#  4   original_language     32671 non-null  object
#  5   popularity            32671 non-null  float64
#  6   production_companies  32671 non-null  object
#  7   production_countries  32671 non-null  object
#  8   release_date          32671 non-null  object
#  9   revenue               32671 non-null  int64
#  10  runtime               32671 non-null  float64
#  11  title                 32671 non-null  object
#  12  video                 32671 non-null  bool
#  13  vote_average          32671 non-null  float64
#  14  vote_count            32671 non-null  int64
# ...

# %%
data
# Out:
#        adult     budget                                        genres      id  \
# 0      False          0                               Romance, Comedy   15602
# 1      False          0              Action, Adventure, Drama, Family   45325
# 2      False          0                                Comedy, Horror   12110
# 3      False          0                               Drama, Thriller    1710
# 4      False          0     Drama, Fantasy, Science Fiction, Thriller   12665
# ...      ...        ...                                           ...     ...
# 45455  False  260000000  Action, Science Fiction, Thriller, Adventure  335988
# 45456  False  270000000   Adventure, Fantasy, Action, Science Fiction    1452
# 45457  False  280000000            Action, Adventure, Science Fiction   99861
# 45458  False  300000000                    Adventure, Fantasy, Action     285
# 45459  False  380000000                    Adventure, Action, Fantasy    1865
#
# ...

# %%
from sklearn.model_selection import train_test_split

x = data.drop(["popularity"], axis=1) #makes a new df drom original data whithout the column "popularity" 
y = data["popularity"] #takes out the target value


#x_train is the independent variables used to train the model in the training phase, y_train contains the corresponding target values which alligns with x_train
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
#x
#y
train_data = x_train.join(y_train)
train_data
# Out:
#        adult    budget                           genres      id  \
# 8218   False         0                      Documentary   99657
# 42966  False  22700000          Comedy, Science Fiction     957
# 6200   False         0                           Comedy    9648
# 26801  False         0  Science Fiction, Action, Horror  347064
# 28884  False         0                    Family, Drama   17575
# ...      ...       ...                              ...     ...
# 14854  False         0                    Comedy, Music   32996
# 946    False         0    Comedy, Drama, Music, Romance   44772
# 31808  False         0       Action, Animation, Fantasy   22154
# 35782  False         0          Action, Crime, Thriller   23587
# 1584   False         0           Comedy, Music, Romance   13368
#
#       original_language                               production_companies  \
# 8218                 de                       Werner Herzog Filmproduktion
# ...

# %%
train_data.hist(figsize=(15,8)) #makes a histogram wuth train_data with particular size, most of them are right skewed
# Out:
# array([[<Axes: title={'center': 'budget'}>,
#         <Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'revenue'}>],
#        [<Axes: title={'center': 'runtime'}>,
#         <Axes: title={'center': 'vote_average'}>,
#         <Axes: title={'center': 'vote_count'}>],
#        [<Axes: title={'center': 'popularity'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
train_data.corr()
# Out:
# C:\Users\luqma\AppData\Local\Temp\ipykernel_3428\467693521.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_data.corr()
#                  adult    budget        id   revenue   runtime     video  \
# adult         1.000000 -0.003906  0.001947 -0.002863 -0.010194 -0.000477
# budget       -0.003906  1.000000 -0.097161  0.766482  0.154531 -0.009441
# id            0.001947 -0.097161  1.000000 -0.068354 -0.103829  0.038853
# revenue      -0.002863  0.766482 -0.068354  1.000000  0.121064 -0.007133
# runtime      -0.010194  0.154531 -0.103829  0.121064  1.000000 -0.018230
# video        -0.000477 -0.009441  0.038853 -0.007133 -0.018230  1.000000
# vote_average -0.010280  0.064663 -0.136181  0.091446  0.153093 -0.017813
# vote_count   -0.003411  0.664946 -0.054605  0.810985  0.129332 -0.008604
# ...

# %%
#train_data.corr().hist(figsize=(15, 8))

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu") #heatmap() function from seaborn sns, annot == annotations true meaning it shows the numbers
# Out:
# C:\Users\luqma\AppData\Local\Temp\ipykernel_3428\2163313077.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu") #heatmap() function from seaborn sns, annot == annotations true meaning it shows the numbers
# <Axes: >

# %%
train_data["budget"] = np.log(train_data["budget"] + 1)
train_data["runtime"] = np.log(train_data["runtime"] + 1)
train_data["revenue"] = np.log(train_data["revenue"] + 1)
train_data["popularity"] = np.log(train_data["popularity"] + 1)

# %%
train_data
# Out:
#        adult     budget                           genres      id  \
# 8218   False   0.000000                      Documentary   99657
# 42966  False  16.937876          Comedy, Science Fiction     957
# 6200   False   0.000000                           Comedy    9648
# 26801  False   0.000000  Science Fiction, Action, Horror  347064
# 28884  False   0.000000                    Family, Drama   17575
# ...      ...        ...                              ...     ...
# 14854  False   0.000000                    Comedy, Music   32996
# 946    False   0.000000    Comedy, Drama, Music, Romance   44772
# 31808  False   0.000000       Action, Animation, Fantasy   22154
# 35782  False   0.000000          Action, Crime, Thriller   23587
# 1584   False   0.000000           Comedy, Music, Romance   13368
#
#       original_language                               production_companies  \
# 8218                 de                       Werner Herzog Filmproduktion
# ...

# %%
train_data = train_data.join(pd.get_dummies(train_data.adult)).drop(["adult"], axis=1)

# %%
train_data
# Out:
#           budget                           genres      id original_language  \
# 8218    0.000000                      Documentary   99657                de
# 42966  16.937876          Comedy, Science Fiction     957                en
# 6200    0.000000                           Comedy    9648                en
# 26801   0.000000  Science Fiction, Action, Horror  347064                en
# 28884   0.000000                    Family, Drama   17575                no
# ...          ...                              ...     ...               ...
# 14854   0.000000                    Comedy, Music   32996                en
# 946     0.000000    Comedy, Drama, Music, Romance   44772                en
# 31808   0.000000       Action, Animation, Fantasy   22154                en
# 35782   0.000000          Action, Crime, Thriller   23587                en
# 1584    0.000000           Comedy, Music, Romance   13368                en
#
# ...

# %%
train_data = train_data.join(pd.get_dummies(train_data.original_language)).drop(["original_language"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 train_data = train_data.join(pd.get_dummies(train_data.original_language)).drop(["original_language"], axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9979, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9816 def join(
#    9817     self,
#    9818     other: DataFrame | Series | list[DataFrame | Series],
#    (...)
#    9824     validate: str | None = None,
#    9825 ) -> DataFrame:
#    9826     """
#    9827     Join columns of another DataFrame.
#    9828
#    (...)
#    9977     5  K1  A5   B1
#    9978     """
# -> 9979     return self._join_compat(
#    9980         other,
#    9981         on=on,
#    9982         how=how,
#    9983         lsuffix=lsuffix,
#    9984         rsuffix=rsuffix,
#    9985         sort=sort,
# ...

# %%
train_data
# Out:
#           budget                           genres      id original_language  \
# 8218    0.000000                      Documentary   99657                de
# 42966  16.937876          Comedy, Science Fiction     957                en
# 6200    0.000000                           Comedy    9648                en
# 26801   0.000000  Science Fiction, Action, Horror  347064                en
# 28884   0.000000                    Family, Drama   17575                no
# ...          ...                              ...     ...               ...
# 14854   0.000000                    Comedy, Music   32996                en
# 946     0.000000    Comedy, Drama, Music, Romance   44772                en
# 31808   0.000000       Action, Animation, Fantasy   22154                en
# 35782   0.000000          Action, Crime, Thriller   23587                en
# 1584    0.000000           Comedy, Music, Romance   13368                en
#
# ...

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# C:\Users\luqma\AppData\Local\Temp\ipykernel_3428\1811937681.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# <Axes: >

# %%
6
